# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelHilario/Praticas-de-dados/blob/main/Pratca_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
##leitura de um csv em dataframe
games = pd.read_csv('steam-200k.csv')
games.shape
# Out:
# (199999, 5)

# %%
games.describe()
# Out:
#           151603712            1.0         0
# count  1.999990e+05  199999.000000  199999.0
# mean   1.036556e+08      17.874468       0.0
# std    7.208084e+07     138.057292       0.0
# min    5.250000e+03       0.100000       0.0
# 25%    4.738420e+07       1.000000       0.0
# 50%    8.691201e+07       1.000000       0.0
# 75%    1.542309e+08       1.300000       0.0
# max    3.099031e+08   11754.000000       0.0

# %%
games.head()
#Primeiros registros
# Out:
#    151603712  The Elder Scrolls V Skyrim  purchase    1.0  0
# 0  151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 1  151603712                   Fallout 4  purchase    1.0  0
# 2  151603712                   Fallout 4      play   87.0  0
# 3  151603712                       Spore  purchase    1.0  0
# 4  151603712                       Spore      play   14.9  0

# %%
#renomear
games.rename(columns={"purchase":"comprar"},inplace=True)

# %%
games.head()
# Out:
#    151603712  The Elder Scrolls V Skyrim   comprar    1.0  0
# 0  151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 1  151603712                   Fallout 4  purchase    1.0  0
# 2  151603712                   Fallout 4      play   87.0  0
# 3  151603712                       Spore  purchase    1.0  0
# 4  151603712                       Spore      play   14.9  0

# %%
#Se existe dados nulos
games.isnull()
# Out:
#         151603712  The Elder Scrolls V Skyrim  comprar    1.0      0
# 0           False                       False    False  False  False
# 1           False                       False    False  False  False
# 2           False                       False    False  False  False
# 3           False                       False    False  False  False
# 4           False                       False    False  False  False
# ...           ...                         ...      ...    ...    ...
# 199994      False                       False    False  False  False
# 199995      False                       False    False  False  False
# 199996      False                       False    False  False  False
# 199997      False                       False    False  False  False
# 199998      False                       False    False  False  False
#
# [199999 rows x 5 columns]
